# %% [markdown]
# Embeddings

# %% [markdown]
# Simple text extraction

# %%
with open("text/the-verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()
print("Total char: ", len(raw_text))
print(raw_text[:99])
# Out:
# Total char:  20479
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no

# %% [markdown]
# Splitting up words

# %%
import re
text = "Texting, Some, diffrent words --?? world hle?!llo"
result = re.split(r'([,.:;?_!"()\']|--|\s)', text)
result = [item.strip() for item in result if item.strip()]
print(result)
# Out:
# ['Texting', ',', 'Some', ',', 'diffrent', 'words', '--', '?', '?', 'world', 'hle', '?', '!', 'llo']

# %% [markdown]
# Tokenizer v1

# %%
class tokenizerV1:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = {i:s for s,i in vocab.items()}

    def encoder(self, text):
        # Split it into words taking weird symbols into consideration and then strip all the blank spaces from the result
        preprocess = re.split(r'([,.:;?_!"()\']|--|\s)', text)
        preprocess = [item.strip() for item in preprocess if item.strip()]
        ids = [self.str_to_int[s] for s in preprocess]
        return ids
    
    def decoder(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        text = re.sub(r'\s+([,.?!"()\'])', r'\1', text)
        return text
